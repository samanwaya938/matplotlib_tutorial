# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.9

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,25,30]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

y = [10,20,25,30]

plt.plot(y)
plt.show()
